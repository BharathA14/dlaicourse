# %%
import json
import tensorflow as tf
import csv
import random
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers


embedding_dim = 100
max_length = 16
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size=160000 #Your dataset size here. Experiment using smaller values (i.e. 16000), but don't forget to train on at least 160000 to see the best effects
test_portion=.1

corpus = []

# %%
# Note that I cleaned the Stanford dataset to remove LATIN1 encoding to make it easier for Python CSV reader
# You can do that yourself with:
# iconv -f LATIN1 -t UTF8 training.1600000.processed.noemoticon.csv -o training_cleaned.csv
# I then hosted it on my site to make it easier to use in this notebook

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv \
    -O /tmp/training_cleaned.csv

num_sentences = 0

with open("/tmp/training_cleaned.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
      # Your Code here. Create list items where the first item is the text, found in row[5], and the second is the label. Note that the label is a '0' or a '4' in the text. When it's the former, make
      # your label to be 0, otherwise 1. Keep a count of the number of sentences in num_sentences
        list_item=[]
        # YOUR CODE HERE
        list_item.append(row[5])
        this_label=row[0]
        if this_label=='0':
            list_item.append(0)
        else:
            list_item.append(1)
        num_sentences = num_sentences + 1
        corpus.append(list_item)
# Out:
# --2020-05-03 06:32:25--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.133.128, 2a00:1450:400c:c09::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.133.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238942690 (228M) [application/octet-stream]
# Saving to: ‘/tmp/training_cleaned.csv’
#
# /tmp/training_clean 100%[===================>] 227.87M  66.5MB/s    in 3.4s
#
# 2020-05-03 06:32:29 (66.5 MB/s) - ‘/tmp/training_cleaned.csv’ saved [238942690/238942690]

# %%
print(num_sentences)
print(len(corpus))
print(corpus[1])

# Expected Output:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]
# Out:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]

# %%
sentences=[]
labels=[]
random.shuffle(corpus)
for x in range(training_size):
    sentences.append(corpus[x][0])
    labels.append(corpus[x][1])


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size=len(word_index)

sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

split = int(test_portion * training_size)

test_sequences = padded[0:split]
training_sequences = padded[split:training_size]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
print(vocab_size)
print(word_index['i'])
# Expected Output
# 138858
# 1
print(word_index.items())
# Out:
# 138428
# 1
# dict_items([('i', 1), ('to', 2), ('the', 3), ('a', 4), ('my', 5), ('and', 6), ('you', 7), ('is', 8), ('it', 9), ('for', 10), ('in', 11), ('of', 12), ('on', 13), ('me', 14), ('so', 15), ('have', 16), ('that', 17), ('but', 18), ("i'm", 19), ('just', 20), ('with', 21), ('be', 22), ('at', 23), ('not', 24), ('was', 25), ('this', 26), ('up', 27), ('now', 28), ('good', 29), ('day', 30), ('out', 31), ('get', 32), ('all', 33), ('like', 34), ('are', 35), ('no', 36), ('go', 37), ('quot', 38), ('http', 39), ('today', 40), ("it's", 41), ('do', 42), ('work', 43), ('too', 44), ('your', 45), ('going', 46), ('love', 47), ('got', 48), ('lol', 49), ('back', 50), ('time', 51), ('from', 52), ('u', 53), ('one', 54), ('what', 55), ('will', 56), ('com', 57), ('know', 58), ('we', 59), ('im', 60), ('about', 61), ('am', 62), ('really', 63), ('amp', 64), ("don't", 65), ('had', 66), ('can', 67), ('its', 68), ('see', 69), ("can't", 70), ('some', 71), ('still', 72), ('2', 73), ('if', 74), ('want', 75), ('well', 76), ('night', 77), ('new', 78), ('how', 79), ('think', 80), ('oh', 81), ('home', 82), ('thanks', 83), ('there', 84), ('more', 85), ('as', 86), ('when', 87), ('miss', 88), ('much', 89), ('they', 90), ('here', 91), ('off', 92), ('need', 93), ('an', 94), ('last', 95), ('then', 96), ('morning', 97), ('tomorrow', 98), ('great', 99), ('hope', 100), ('has', 101), ('or', 102), ('twitter', 103), ('been', 104), ('3', 105), ('haha', 106), ('again', 107), ('feel', 108), ('her', 109), ('sad', 110), ('fun', 111), ('only', 112), ('sleep', 113), ('he', 114), ('why', 115), ('wish', 116), ('right', 117), ('bad', 118), ('did', 119), ('happy', 120), ('sorry', 121), ('would', 122), ('very', 123), ('tonight', 124), ("i'll", 125), ('by', 126), ('make', 127), ('come', 128), ('way', 129), ('nice', 130), ('them', 131), ('getting', 132), ('bit', 133), ('though', 134), ('better', 135), ('gonna', 136), ('over', 137), ('bed', 138), ('yeah', 139), ('she', 140), ('should', 141), ('watching', 142), ("that's", 143), ('week', 144), ('wait', 145), ("didn't", 146), ('twitpic', 147), ('people', 148), ('could', 149), ('hey', 150), ('even', 151), ("you're", 152), ("i've", 153), ('days', 154), ('hate', 155), ('school', 156), ('after', 157), ('yes', 158), ('him', 159), ('4', 160), ('down', 161), ('awesome', 162), ('weekend', 163), ('next', 164), ('never', 165), ('were', 166), ('dont', 167), ('lt', 168), ('soon', 169), ('working', 170), ('tired', 171), ('cant', 172), ('thank', 173), ('ok', 174), ('who', 175), ('little', 176), ('take', 177), ('please', 178), ('having', 179), ('long', 180), ('x', 181), ('watch', 182), ('life', 183), ('doing', 184), ('wanna', 185), ('say', 186), ('sick', 187), ('show', 188), ('first', 189), ('his', 190), ('everyone', 191), ('us', 192), ('1', 193), ('best', 194), ('feeling', 195), ('always', 196), ('any', 197), ('being', 198), ('thing', 199), ('done', 200), ('sure', 201), ('another', 202), ('than', 203), ('cool', 204), ('our', 205), ('man', 206), ('friends', 207), ('ready', 208), ('where', 209), ('already', 210), ('something', 211), ('went', 212), ('made', 213), ('find', 214), ('looking', 215), ('guys', 216), ('because', 217), ('yay', 218), ('ly', 219), ('ur', 220), ('before', 221), ('look', 222), ('house', 223), ('phone', 224), ('yet', 225), ('maybe', 226), ('p', 227), ('ever', 228), ('hours', 229), ('movie', 230), ('tweet', 231), ('pretty', 232), ('trying', 233), ('early', 234), ('omg', 235), ('5', 236), ('follow', 237), ('old', 238), ('finally', 239), ('summer', 240), ('amazing', 241), ('away', 242), ('into', 243), ('guess', 244), ('keep', 245), ('lost', 246), ('damn', 247), ('help', 248), ('things', 249), ('someone', 250), ('left', 251), ('missed', 252), ('let', 253), ('big', 254), ('wow', 255), ('hot', 256), ('year', 257), ('nothing', 258), ('live', 259), ('n', 260), ('sucks', 261), ('thought', 262), ('friend', 263), ('two', 264), ('while', 265), ('girl', 266), ('baby', 267), ('looks', 268), ('rain', 269), ('same', 270), ('also', 271), ('actually', 272), (' ...

# %%
# Note this is the 100 dimension version of GloVe from Stanford
# I unzipped and hosted it on my site to make this notebook easier
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/tmp/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;

embeddings_matrix = np.zeros((vocab_size+1, embedding_dim));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2020-05-03 06:33:01--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.15.128, 2a00:1450:400c:c08::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.15.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 347116733 (331M) [text/plain]
# Saving to: ‘/tmp/glove.6B.100d.txt’
#
# /tmp/glove.6B.100d. 100%[===================>] 331.04M  63.7MB/s    in 5.2s
#
# 2020-05-03 06:33:06 (63.7 MB/s) - ‘/tmp/glove.6B.100d.txt’ saved [347116733/347116733]

# %%
print(len(embeddings_matrix))
# Expected Output
# 138859
# Out:
# 138429

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, embedding_dim, input_length=max_length, weights=[embeddings_matrix], trainable=False),
    # YOUR CODE HERE - experiment with combining different types, such as convolutions and LSTMs
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv1D(64, 3, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50
history = model.fit(training_sequences, training_labels, epochs=num_epochs, validation_data=(test_sequences, test_labels), verbose=2)

print("Training Complete")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 16, 100)           13842900
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 100)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 14, 64)            19264
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 3, 64)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 13,895,253
# Trainable params: 52,353
# Non-trainable params: 13,842,900
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-22f17cdec5c3> in <module>()
#      12
#      13 num_epochs = 50
# ---> 14 history = model.fit(training_sequences, training_labels, epochs=num_epochs, validation_data=(test_sequences, test_labels), verbose=2)
#      15
#      16 print("Training Complete")
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     816           workers=workers,
#     817           use_multiprocessing=use_multiprocessing,
# --> 818           model=self)
#     819
#     820       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model)
#    1097     self._insufficient_data = False
#    1098
# -> 1099     adapter_cls = select_data_adapter(x, y)
#    1100     self._adapter = adapter_cls(
#    1101         x,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in select_data_adapter(x, y)
#     961         "Failed to find data adapter that can handle "
#     962         "input: {}, {}".format(
# --> 963             _type_name(x), _type_name(y)))
#     964   elif len(adapter_cls) > 1:
#     965     raise RuntimeError(
#
# ValueError: Failed to find data adapter that can handle input: <class 'numpy.ndarray'>, (<class 'list'> containing values of types {"<class 'int'>"})

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['acc']
val_acc=history.history['val_acc']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])

plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])

plt.figure()


# Expected Output
# A chart where the validation loss does not increase sharply!
